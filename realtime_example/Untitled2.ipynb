# %%
import QUANTAXIS as qa
from QIFIAccount import QIFI_Account,QA_Position
from QIFIAccount.QASimAccount import QIFI_SIM_Account
import pandas as pd

# %%
username='myacc12'
my=QIFI_SIM_Account(username=username,password=username)
my.initial()
# Out:
# Create new Account

# %%
df=pd.read_excel("E:\\leo\\投资\\2021\\股票持仓分析20210509-快照20210520.xlsx",sheet_name="持仓明细详情",header=6)
df=df[df['pos_num']>0]
code_cn_list=list(x.split(".")[0] for x in df.code[df['currency']=='CNY'].unique().tolist())
code_cn_list
code_hk_list=list(x.split(".")[0] for x in df.code[df['currency']=='HK'].unique().tolist())
code_hk_list=[i.rjust(5,'0') if len(i)==4  else i for i in code_hk_list]

# %%
def add_position(stock):
    code=stock['code'].split('.')
    if len(code[0])==6 and stock['currency']=='CNY':
        code=code[0]
        market_type=qa.MARKET_TYPE.STOCK_CN
        exchange_id=qa.EXCHANGE_ID.SZSE if stock['code'][0] in (0,3) else qa.EXCHANGE_ID.SSE
    elif len(code[0])==6:
        code=code[0]
        market_type='stock_cn_b'
        exchange_id=qa.EXCHANGE_ID.SZSE
    else:
        code=str(code[0]).rjust(5,'0')
        market_type='stock_hk'
        exchange_id='hk'
    pos=QA_Position(
                code=code,
                account_cookie=username,
                market_type=market_type,
                exchange_id=exchange_id,
                volume_long_his=stock['pos_num'],
                volume_long_today=0,
                open_price_long=stock['cost'],
                name=stock['name'])
    my.add_position(pos)
def s(x):
    print(type(x['code']),x['code'].split('.'))

# %%
day='2021-06-25'
for code in code_cn_list:
    price=qa.QA_fetch_get_stock_day('tdx',code,day,day)
    price.apply(lambda x:my.on_price_change(code,x.close,datetime=x.date),axis=1)
for code in code_hk_list:
    price=qa.QA_fetch_get_hkstock_day('tdx',code,day,day) if len(code)==5 else qa.QA_fetch_get_stock_day('tdx',code,day,day)
    price.apply(lambda x:my.on_price_change(code,x.close*0.8244,datetime=x.date),axis=1)

# %%
df.groupby('code').agg({'pos_num':'sum','cost':'mean','name':'first','currency':'first'}).reset_index().apply(lambda x:s(x),axis=1)
# Out:
#                    code instrument_id  user_id portfolio_cookie   username  \
# stock_cn.000333  000333        000333  myacc12        portfolio  quantaxis
# stock_cn.000961  000961        000961  myacc12        portfolio  quantaxis
# stock_cn.002027  002027        002027  myacc12        portfolio  quantaxis
# stock_cn.002353  002353        002353  myacc12        portfolio  quantaxis
# stock_cn.00700    00700         00700  myacc12        portfolio  quantaxis
# stock_cn.01088    01088         01088  myacc12        portfolio  quantaxis
# stock_cn.01516    01516         01516  myacc12        portfolio  quantaxis
# stock_cn.159920  159920        159920  myacc12        portfolio  quantaxis
# stock_cn.160322  160322        160322  myacc12        portfolio  quantaxis
# stock_cn.160631  160631        160631  myacc12        portfolio  quantaxis
# stock_cn.161121  161121        161121  myacc12        portfolio  quantaxis
# stock_cn.01918    01918         01918  myacc12        portfolio  quantaxis
# stock_cn.200625  200625        200625  myacc12        portfolio  quantaxis
# stock_cn.02007    02007         02007  myacc12        portfolio  quantaxis
# stock_cn.502020  502020        502020  myacc12        portfolio  quantaxis
# stock_cn.510050  510050        510050  myacc12        portfolio  quantaxis
# stock_cn.510880  510880        510880  myacc12        portfolio  quantaxis
# stock_cn.510900  510900        510900  myacc12        portfolio  quantaxis
# stock_cn.512800  512800        512800  myacc12        portfolio  quantaxis
# stock_cn.600036  600036        600036  myacc12        portfolio  quantaxis
# stock_cn.600516  600516        600516  myacc12        portfolio  quantaxis
# stock_cn.600985  600985        600985  myacc12        portfolio  quantaxis
# stock_cn.601166  601166        601166  myacc12        portfolio  quantaxis
# stock_cn.601225  601225        601225  myacc12        portfolio  quantaxis
# stock_cn.601318  601318        601318  myacc12        portfolio  quantaxis
# stock_cn.601668  601668        601668  myacc12        portfolio  quantaxis
# stock_cn.601939  601939        601939  myacc12        portfolio  quantaxis
#
#                                           position_id account_cookie frozen  \
# stock_cn.000333  2e9d5acf-d815-47cb-b050-e2875ae9355e        myacc12     {}
# stock_cn.000961  c4159ef6-06d0-4bff-bc4a-1c9bc1e47cb5        myacc12     {}
# stock_cn.002027  b9df54fc-887d-4bdf-bd64-e5f5bf1cdaeb        myacc12     {}
# stock_cn.002353  e7502eb3-0ad8-4911-91bd-f090906df380        myacc12     {}
# stock_cn.00700   45cd967f-7f61-455b-b77a-47d028a724b9        myacc12     {}
# stock_cn.01088   64fba7fc-e6f4-4d7d-9579-c0c5d4f64664        myacc12     {}
# stock_cn.01516   514cfd79-78b8-4542-acc4-d11e4512e33e        myacc12     {}
# stock_cn.159920  82ee35fc-f843-4b6a-bd1e-f117fc2f8ffe        myacc12     {}
# stock_cn.160322  71315565-4692-46df-8620-a0d3630d3008        myacc12     {}
# stock_cn.160631  3b7c743d-5b69-4f96-8e7c-557b21056bba        myacc12     {}
# stock_cn.161121  5f2884bb-f0fe-4bfe-b3d4-676c21095529        myacc12     {}
# stock_cn.01918   3f1ff50e-b33e-43d1-820f-63f62df275a6        myacc12     {}
# stock_cn.200625  b9a16a03-1b4e-4788-8b1a-f1065ce0f43b        myacc12     {}
# stock_cn.02007   d2e24728-aa68-4fc4-986f-a4cf521dc438        myacc12     {}
# stock_cn.502020  d1ee8246-0f1d-459b-af00-ba56eef533a4        myacc12     {}
# stock_cn.510050  885ccb02-b37e-4009-bc8b-6ef735d06638        myacc12     {}
# stock_cn.510880  4df1d4a3-5c3c-429a-9f1b-7fb4dc705e13        myacc12     {}
# stock_cn.510900  66b14f94-f679-432a-b107-022273270430        myacc12     {}
# stock_cn.512800  4c9f7c53-0775-4866-b63f-a19e1a537e31        myacc12     {}
# stock_cn.600036  2e938f06-b3d2-4c07-951c-f90b157cafab        myacc12     {}
# stock_cn.600516  edfe7f9e-062d-40cb-9faf-9a2533627649        myacc12     {}
# stock_cn.600985  7d1ffa69-1ca6-494c-a2e5-df6e5da4cdad        myacc12     {}
# stock_cn.601166  1c04b2f5-93a5-442b-8aed-77cb9b09847b        myacc12     {}
# stock_cn.601225  b1edb1f4-1380-4c3d-8bd8-704d0eddf62c        myacc12     {}
# stock_cn.601318  c33946ae-51ce-472b-bb8e-fc21a0b07a98        myacc12     {}
# stock_cn.601668  8da5044d-5f3d-4dd3-83b9-783bc8f7556c        myacc12     {}
# stock_cn.601939  1a6d073b-109f-4038-b6dd-72d33fb4ceff        myacc12     {}
#
#                       name spms_id  ... open_cost_short trades orders  \
# stock_cn.000333       美的集团    None  ...               0     []     {}
# stock_cn.000961       中南建设    None  ...               0     []     {}
# stock_cn.002027       分众传媒    None  ...               0     []     {}
# stock_cn.002353       杰瑞股份    None  ...               0     []     {}
# stock_cn.00700        腾讯控股    None  ...               0     []     {}
# stock_cn.01088        中国神华    None  ...               0     []     {}
# stock_cn.01516        融创服务    None  ...               0     []     {}
# stock_cn.159920      恒生ETF    None  ...               0     []     {}
# stock_cn.160322       港股精选    None  ...               0     []     {}
# stock_cn.160631       银行指基    None  ...               0     []     {}
# stock_cn.161121         银行    None  ...               0     []     {}
# stock_cn.01918        融创中国    None  ...               0     []     {}
# stock_cn.200625        长安B    None  ...               0     []     {}
# stock_cn.02007         碧桂园    None  ...               0     []     {}
# stock_cn.502020  上证50增强LOF    None  ...               0     []     {}
# stock_cn.510050    上证50ETF    None  ...               0     []     {}
# stock_cn.510880      红利ETF    None  ...               0     []     {}
# stock_cn.510900      H股ETF    None  ...               0     []     {}
# stock_cn.512800      银行ETF    None  ...               0     []     {}
# stock_cn.600036       招商银行    None  ...               0     []     {}
# stock_cn.600516       方大炭素    None  ...               0     []     {}
# stock_cn.600985       淮北矿业    None  ...               0     []     {}
# stock_cn.601166       兴业银行    None  ...               0     []     {}
# stock_cn.601225       陕西煤业    None  ...               0     []     {}
# stock_cn.601318       中国平安    None  ...               0     []     {}
# stock_cn.601668       中国建筑    None  ...               0     []     {}
# stock_cn.601939       建设银行    None  ...               0     []     {}
#
#                 last_price float_profit_long float_profit_short float_profit  \
# stock_cn.000333      73.17           8033.52                  0      8033.52
# stock_cn.000961          6            -16956                  0       -16956
# stock_cn.002027       9.15           40182.8                  0      40182.8
# stock_cn.002353      45.26            3898.5                  0       3898.5
# stock_cn.00700     493.403           7633.16                  0      7633.16
# stock_cn.01088     14.7403          -2636.73                  0     -2636.73
# stock_cn.01516        22.3           164.481                  0      164.481
# stock_cn.159920      1.523             -89.4                  0        -89.4
# stock_cn.160322      1.714            -229.6                  0       -229.6
# stock_cn.160631      1.046           112.562                  0      112.562
# stock_cn.161121      1.223             39.69                  0        39.69
# stock_cn.01918     22.6298           16248.8                  0      16248.8
# stock_cn.200625    6.54574          -18955.5                  0     -18955.5
# stock_cn.02007     7.43609          -3856.27                  0     -3856.27
# stock_cn.502020       1.28            -66.96                  0       -66.96
# stock_cn.510050      3.541            2729.1                  0       2729.1
# stock_cn.510880      2.895              1852                  0         1852
# stock_cn.510900      1.173            -281.2                  0       -281.2
# stock_cn.512800      1.247              4425                  0         4425
# stock_cn.600036       56.4           51693.4                  0      51693.4
# stock_cn.600516       7.84          -5612.38                  0     -5612.38
# stock_cn.600985      13.56           13100.7                  0      13100.7
# stock_cn.601166      20.72            194689                  0       194689
# stock_cn.601225      12.51           56311.5                  0      56311.5
# stock_cn.601318      66.68            1412.1                  0       1412.1
# stock_cn.601668       4.92                24                  0           24
# stock_cn.601939       6.74              -252                  0         -252
#
#                 position_profit_long position_profit_short position_profit
# stock_cn.000333              8033.52                     0         8033.52
# stock_cn.000961               -16956                     0          -16956
# stock_cn.002027              40182.8                     0         40182.8
# stock_cn.002353               3898.5                     0          3898.5
# stock_cn.00700               7633.16                     0         7633.16
# stock_cn.01088              -2636.73                     0        -2636.73
# stock_cn.01516               164.481                     0         164.481
# stock_cn.159920                -89.4                     0           -89.4
# stock_cn.160322               -229.6                     0          -229.6
# stock_cn.160631              112.562                     0         112.562
# stock_cn.161121                39.69                     0           39.69
# stock_cn.01918               16248.8                     0         16248.8
# stock_cn.200625             -18955.5                     0        -18955.5
# stock_cn.02007              -3856.27                     0        -3856.27
# stock_cn.502020               -66.96                     0          -66.96
# stock_cn.510050               2729.1                     0          2729.1
# stock_cn.510880                 1852                     0            1852
# stock_cn.510900               -281.2                     0          -281.2
# stock_cn.512800                 4425                     0            4425
# stock_cn.600036              51693.4                     0         51693.4
# stock_cn.600516             -5612.38                     0        -5612.38
# stock_cn.600985              13100.7                     0         13100.7
# stock_cn.601166               194689                     0          194689
# stock_cn.601225              56311.5                     0         56311.5
# stock_cn.601318               1412.1                     0          1412.1
# stock_cn.601668                   24                     0              24
# stock_cn.601939                 -252                     0            -252
#
# [27 rows x 54 columns]

# %%
my.settle()
# Out:
# settle

# %%
my.balance
# Out:
# 3088730.161620059

# %%
my.pre_balance
# Out:
# 2735115.713

# %%
my.position_profit
# Out:
# 353614.4486200593

# %%
my.close_profit
# Out:
# 0

# %%
df1[~(df1['exchange_id']=='hk')]['balance'].sum()
# Out:
# 0

# %%
df1['balance'].sum()
# Out:
# 0

# %%
price=qa.QA_fetch_get_stock_day('tdx','000333',day,day)
price
# Out:
#              open  close   high    low       vol        amount        date  \
# date
# 2021-06-25  73.57  73.17  73.78  72.58  412552.0  3.019079e+09  2021-06-25
#
#               code    date_stamp
# date
# 2021-06-25  000333  1.624550e+09

# %%
my.on_price_change('sse.000333',73.17)

# %%
my.positions.keys()
# Out:
# dict_keys(['stock_cn.000333', 'stock_cn.000961', 'stock_cn.002027', 'stock_cn.002353', 'stock_cn.00700', 'stock_cn.01088', 'stock_cn.01516', 'stock_cn.159920', 'stock_cn.160322', 'stock_cn.160631', 'stock_cn.161121', 'stock_cn.01918', 'stock_cn.200625', 'stock_cn.02007', 'stock_cn.502020', 'stock_cn.510050', 'stock_cn.510880', 'stock_cn.510900', 'stock_cn.512800', 'stock_cn.600036', 'stock_cn.600516', 'stock_cn.600985', 'stock_cn.601166', 'stock_cn.601225', 'stock_cn.601318', 'stock_cn.601668', 'stock_cn.601939'])

# %%
df=pd.DataFrame(my.position_msg).T
df1=df[['code','name','exchange_id','volume_long_his','pos_long_his','open_price_long','last_price','position_profit','position_cost_long']].assign(balance=df['last_price']*df['pos_long_his'])
df1
# Out:
#                    code       name exchange_id volume_long_his pos_long_his  \
# stock_cn.000333  000333       美的集团         sse             374          374
# stock_cn.000961  000961       中南建设         sse           13500        13500
# stock_cn.002027  002027       分众传媒         sse           12700        12700
# stock_cn.002353  002353       杰瑞股份         sse             300          300
# stock_cn.00700    00700       腾讯控股          hk             400          400
# stock_cn.01088    01088       中国神华          hk           12000        12000
# stock_cn.01516    01516       融创服务          hk              32           32
# stock_cn.159920  159920      恒生ETF         sse           44700        44700
# stock_cn.160322  160322       港股精选         sse            2800         2800
# stock_cn.160631  160631       银行指基         sse            2447         2447
# stock_cn.161121  161121         银行         sse            4410         4410
# stock_cn.01918    01918       融创中国          hk            1000         1000
# stock_cn.200625  200625        长安B        szse            4300         4300
# stock_cn.02007    02007        碧桂园          hk            6302         6302
# stock_cn.502020  502020  上证50增强LOF         sse             720          720
# stock_cn.510050  510050    上证50ETF         sse            3300         3300
# stock_cn.510880  510880      红利ETF         sse            4000         4000
# stock_cn.510900  510900      H股ETF         sse           14800        14800
# stock_cn.512800  512800      银行ETF         sse           30000        30000
# stock_cn.600036  600036       招商银行         sse            3300         3300
# stock_cn.600516  600516       方大炭素         sse            1043         1043
# stock_cn.600985  600985       淮北矿业         sse            5066         5066
# stock_cn.601166  601166       兴业银行         sse           32200        32200
# stock_cn.601225  601225       陕西煤业         sse           15500        15500
# stock_cn.601318  601318       中国平安         sse             900          900
# stock_cn.601668  601668       中国建筑         sse            2000         2000
# stock_cn.601939  601939       建设银行         sse            3600         3600
#
#                 open_price_long last_price position_profit position_cost_long  \
# stock_cn.000333           51.69      73.17         8033.52            19332.1
# stock_cn.000961           7.256          6          -16956              97956
# stock_cn.002027           5.986       9.15         40182.8            76022.2
# stock_cn.002353          32.265      45.26          3898.5             9679.5
# stock_cn.00700          474.321    493.403         7633.16             189728
# stock_cn.01088            14.96    14.7403        -2636.73             179520
# stock_cn.01516            17.16       22.3         164.481             549.12
# stock_cn.159920           1.525      1.523           -89.4            68167.5
# stock_cn.160322           1.796      1.714          -229.6             5028.8
# stock_cn.160631               1      1.046         112.562               2447
# stock_cn.161121           1.214      1.223           39.69            5353.74
# stock_cn.01918            6.381    22.6298         16248.8               6381
# stock_cn.200625          10.954    6.54574        -18955.5            47102.2
# stock_cn.02007            8.048    7.43609        -3856.27            50718.5
# stock_cn.502020           1.373       1.28          -66.96             988.56
# stock_cn.510050           2.714      3.541          2729.1             8956.2
# stock_cn.510880           2.432      2.895            1852               9728
# stock_cn.510900           1.192      1.173          -281.2            17641.6
# stock_cn.512800          1.0995      1.247            4425              32985
# stock_cn.600036         40.7353       56.4         51693.4             134427
# stock_cn.600516          13.221       7.84        -5612.38            13789.5
# stock_cn.600985          10.974      13.56         13100.7            55594.3
# stock_cn.601166         14.6738      20.72          194689             472495
# stock_cn.601225           8.877      12.51         56311.5             137593
# stock_cn.601318          65.111      66.68          1412.1            58599.9
# stock_cn.601668           4.908       4.92              24               9816
# stock_cn.601939            6.81       6.74            -252              24516
#
#                  balance
# stock_cn.000333  27365.6
# stock_cn.000961    81000
# stock_cn.002027   116205
# stock_cn.002353    13578
# stock_cn.00700    197361
# stock_cn.01088    176883
# stock_cn.01516   713.601
# stock_cn.159920  68078.1
# stock_cn.160322   4799.2
# stock_cn.160631  2559.56
# stock_cn.161121  5393.43
# stock_cn.01918   22629.8
# stock_cn.200625  28146.7
# stock_cn.02007   46862.2
# stock_cn.502020    921.6
# stock_cn.510050  11685.3
# stock_cn.510880    11580
# stock_cn.510900  17360.4
# stock_cn.512800    37410
# stock_cn.600036   186120
# stock_cn.600516  8177.12
# stock_cn.600985    68695
# stock_cn.601166   667184
# stock_cn.601225   193905
# stock_cn.601318    60012
# stock_cn.601668     9840
# stock_cn.601939    24264

# %%
df.T
# Out:
#                                                 stock_cn.000333  \
# code                                                     000333
# instrument_id                                            000333
# user_id                                                 myacc12
# portfolio_cookie                                      portfolio
# username                                              quantaxis
# position_id                2e9d5acf-d815-47cb-b050-e2875ae9355e
# account_cookie                                          myacc12
# frozen                                                       {}
# name                                                       美的集团
# spms_id                                                    None
# oms_id                                                     None
# market_type                                            stock_cn
# exchange_id                                                 sse
# moneypreset                                              100000
# moneypresetLeft                                          100000
# lastupdatetime
# volume_long_today                                             0
# volume_long_his                                             374
# volume_long                                                 374
# volume_long_yd                                                0
# volume_short_yd                                               0
# volume_short_today                                            0
# volume_short_his                                              0
# volume_short                                                  0
# pos_long_his                                                374
# pos_long_today                                                0
# pos_short_his                                                 0
# pos_short_today                                               0
# volume_long_frozen_today                                      0
# volume_long_frozen_his                                        0
# volume_long_frozen                                            0
# volume_short_frozen_today                                     0
# volume_short_frozen_his                                       0
# volume_short_frozen                                           0
# margin_long                                                   0
# margin_short                                                  0
# margin                                                        0
# position_price_long                                       51.69
# position_cost_long                                      19332.1
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                           51.69
# open_cost_long                                          19332.1
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                                73.17
# float_profit_long                                       8033.52
# float_profit_short                                            0
# float_profit                                            8033.52
# position_profit_long                                    8033.52
# position_profit_short                                         0
# position_profit                                         8033.52
#
#                                                 stock_cn.000961  \
# code                                                     000961
# instrument_id                                            000961
# user_id                                                 myacc12
# portfolio_cookie                                      portfolio
# username                                              quantaxis
# position_id                c4159ef6-06d0-4bff-bc4a-1c9bc1e47cb5
# account_cookie                                          myacc12
# frozen                                                       {}
# name                                                       中南建设
# spms_id                                                    None
# oms_id                                                     None
# market_type                                            stock_cn
# exchange_id                                                 sse
# moneypreset                                              100000
# moneypresetLeft                                          100000
# lastupdatetime
# volume_long_today                                             0
# volume_long_his                                           13500
# volume_long                                               13500
# volume_long_yd                                                0
# volume_short_yd                                               0
# volume_short_today                                            0
# volume_short_his                                              0
# volume_short                                                  0
# pos_long_his                                              13500
# pos_long_today                                                0
# pos_short_his                                                 0
# pos_short_today                                               0
# volume_long_frozen_today                                      0
# volume_long_frozen_his                                        0
# volume_long_frozen                                            0
# volume_short_frozen_today                                     0
# volume_short_frozen_his                                       0
# volume_short_frozen                                           0
# margin_long                                                   0
# margin_short                                                  0
# margin                                                        0
# position_price_long                                       7.256
# position_cost_long                                        97956
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                           7.256
# open_cost_long                                            97956
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                                    6
# float_profit_long                                        -16956
# float_profit_short                                            0
# float_profit                                             -16956
# position_profit_long                                     -16956
# position_profit_short                                         0
# position_profit                                          -16956
#
#                                                 stock_cn.002027  \
# code                                                     002027
# instrument_id                                            002027
# user_id                                                 myacc12
# portfolio_cookie                                      portfolio
# username                                              quantaxis
# position_id                b9df54fc-887d-4bdf-bd64-e5f5bf1cdaeb
# account_cookie                                          myacc12
# frozen                                                       {}
# name                                                       分众传媒
# spms_id                                                    None
# oms_id                                                     None
# market_type                                            stock_cn
# exchange_id                                                 sse
# moneypreset                                              100000
# moneypresetLeft                                          100000
# lastupdatetime
# volume_long_today                                             0
# volume_long_his                                           12700
# volume_long                                               12700
# volume_long_yd                                                0
# volume_short_yd                                               0
# volume_short_today                                            0
# volume_short_his                                              0
# volume_short                                                  0
# pos_long_his                                              12700
# pos_long_today                                                0
# pos_short_his                                                 0
# pos_short_today                                               0
# volume_long_frozen_today                                      0
# volume_long_frozen_his                                        0
# volume_long_frozen                                            0
# volume_short_frozen_today                                     0
# volume_short_frozen_his                                       0
# volume_short_frozen                                           0
# margin_long                                                   0
# margin_short                                                  0
# margin                                                        0
# position_price_long                                       5.986
# position_cost_long                                      76022.2
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                           5.986
# open_cost_long                                          76022.2
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                                 9.15
# float_profit_long                                       40182.8
# float_profit_short                                            0
# float_profit                                            40182.8
# position_profit_long                                    40182.8
# position_profit_short                                         0
# position_profit                                         40182.8
#
#                                                 stock_cn.002353  \
# code                                                     002353
# instrument_id                                            002353
# user_id                                                 myacc12
# portfolio_cookie                                      portfolio
# username                                              quantaxis
# position_id                e7502eb3-0ad8-4911-91bd-f090906df380
# account_cookie                                          myacc12
# frozen                                                       {}
# name                                                       杰瑞股份
# spms_id                                                    None
# oms_id                                                     None
# market_type                                            stock_cn
# exchange_id                                                 sse
# moneypreset                                              100000
# moneypresetLeft                                          100000
# lastupdatetime
# volume_long_today                                             0
# volume_long_his                                             300
# volume_long                                                 300
# volume_long_yd                                                0
# volume_short_yd                                               0
# volume_short_today                                            0
# volume_short_his                                              0
# volume_short                                                  0
# pos_long_his                                                300
# pos_long_today                                                0
# pos_short_his                                                 0
# pos_short_today                                               0
# volume_long_frozen_today                                      0
# volume_long_frozen_his                                        0
# volume_long_frozen                                            0
# volume_short_frozen_today                                     0
# volume_short_frozen_his                                       0
# volume_short_frozen                                           0
# margin_long                                                   0
# margin_short                                                  0
# margin                                                        0
# position_price_long                                      32.265
# position_cost_long                                       9679.5
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                          32.265
# open_cost_long                                           9679.5
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                                45.26
# float_profit_long                                        3898.5
# float_profit_short                                            0
# float_profit                                             3898.5
# position_profit_long                                     3898.5
# position_profit_short                                         0
# position_profit                                          3898.5
#
#                                                  stock_cn.00700  \
# code                                                      00700
# instrument_id                                             00700
# user_id                                                 myacc12
# portfolio_cookie                                      portfolio
# username                                              quantaxis
# position_id                45cd967f-7f61-455b-b77a-47d028a724b9
# account_cookie                                          myacc12
# frozen                                                       {}
# name                                                       腾讯控股
# spms_id                                                    None
# oms_id                                                     None
# market_type                                            stock_hk
# exchange_id                                                  hk
# moneypreset                                              100000
# moneypresetLeft                                          100000
# lastupdatetime
# volume_long_today                                             0
# volume_long_his                                             400
# volume_long                                                 400
# volume_long_yd                                                0
# volume_short_yd                                               0
# volume_short_today                                            0
# volume_short_his                                              0
# volume_short                                                  0
# pos_long_his                                                400
# pos_long_today                                                0
# pos_short_his                                                 0
# pos_short_today                                               0
# volume_long_frozen_today                                      0
# volume_long_frozen_his                                        0
# volume_long_frozen                                            0
# volume_short_frozen_today                                     0
# volume_short_frozen_his                                       0
# volume_short_frozen                                           0
# margin_long                                                   0
# margin_short                                                  0
# margin                                                        0
# position_price_long                                     474.321
# position_cost_long                                       189728
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                         474.321
# open_cost_long                                           189728
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                              493.403
# float_profit_long                                       7633.16
# float_profit_short                                            0
# float_profit                                            7633.16
# position_profit_long                                    7633.16
# position_profit_short                                         0
# position_profit                                         7633.16
#
#                                                  stock_cn.01088  \
# code                                                      01088
# instrument_id                                             01088
# user_id                                                 myacc12
# portfolio_cookie                                      portfolio
# username                                              quantaxis
# position_id                64fba7fc-e6f4-4d7d-9579-c0c5d4f64664
# account_cookie                                          myacc12
# frozen                                                       {}
# name                                                       中国神华
# spms_id                                                    None
# oms_id                                                     None
# market_type                                            stock_hk
# exchange_id                                                  hk
# moneypreset                                              100000
# moneypresetLeft                                          100000
# lastupdatetime
# volume_long_today                                             0
# volume_long_his                                           12000
# volume_long                                               12000
# volume_long_yd                                                0
# volume_short_yd                                               0
# volume_short_today                                            0
# volume_short_his                                              0
# volume_short                                                  0
# pos_long_his                                              12000
# pos_long_today                                                0
# pos_short_his                                                 0
# pos_short_today                                               0
# volume_long_frozen_today                                      0
# volume_long_frozen_his                                        0
# volume_long_frozen                                            0
# volume_short_frozen_today                                     0
# volume_short_frozen_his                                       0
# volume_short_frozen                                           0
# margin_long                                                   0
# margin_short                                                  0
# margin                                                        0
# position_price_long                                       14.96
# position_cost_long                                       179520
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                           14.96
# open_cost_long                                           179520
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                              14.7403
# float_profit_long                                      -2636.73
# float_profit_short                                            0
# float_profit                                           -2636.73
# position_profit_long                                   -2636.73
# position_profit_short                                         0
# position_profit                                        -2636.73
#
#                                                  stock_cn.01516  \
# code                                                      01516
# instrument_id                                             01516
# user_id                                                 myacc12
# portfolio_cookie                                      portfolio
# username                                              quantaxis
# position_id                514cfd79-78b8-4542-acc4-d11e4512e33e
# account_cookie                                          myacc12
# frozen                                                       {}
# name                                                       融创服务
# spms_id                                                    None
# oms_id                                                     None
# market_type                                            stock_hk
# exchange_id                                                  hk
# moneypreset                                              100000
# moneypresetLeft                                          100000
# lastupdatetime
# volume_long_today                                             0
# volume_long_his                                              32
# volume_long                                                  32
# volume_long_yd                                                0
# volume_short_yd                                               0
# volume_short_today                                            0
# volume_short_his                                              0
# volume_short                                                  0
# pos_long_his                                                 32
# pos_long_today                                                0
# pos_short_his                                                 0
# pos_short_today                                               0
# volume_long_frozen_today                                      0
# volume_long_frozen_his                                        0
# volume_long_frozen                                            0
# volume_short_frozen_today                                     0
# volume_short_frozen_his                                       0
# volume_short_frozen                                           0
# margin_long                                                   0
# margin_short                                                  0
# margin                                                        0
# position_price_long                                       17.16
# position_cost_long                                       549.12
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                           17.16
# open_cost_long                                           549.12
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                                 22.3
# float_profit_long                                       164.481
# float_profit_short                                            0
# float_profit                                            164.481
# position_profit_long                                    164.481
# position_profit_short                                         0
# position_profit                                         164.481
#
#                                                 stock_cn.159920  \
# code                                                     159920
# instrument_id                                            159920
# user_id                                                 myacc12
# portfolio_cookie                                      portfolio
# username                                              quantaxis
# position_id                82ee35fc-f843-4b6a-bd1e-f117fc2f8ffe
# account_cookie                                          myacc12
# frozen                                                       {}
# name                                                      恒生ETF
# spms_id                                                    None
# oms_id                                                     None
# market_type                                            stock_cn
# exchange_id                                                 sse
# moneypreset                                              100000
# moneypresetLeft                                          100000
# lastupdatetime
# volume_long_today                                             0
# volume_long_his                                           44700
# volume_long                                               44700
# volume_long_yd                                                0
# volume_short_yd                                               0
# volume_short_today                                            0
# volume_short_his                                              0
# volume_short                                                  0
# pos_long_his                                              44700
# pos_long_today                                                0
# pos_short_his                                                 0
# pos_short_today                                               0
# volume_long_frozen_today                                      0
# volume_long_frozen_his                                        0
# volume_long_frozen                                            0
# volume_short_frozen_today                                     0
# volume_short_frozen_his                                       0
# volume_short_frozen                                           0
# margin_long                                                   0
# margin_short                                                  0
# margin                                                        0
# position_price_long                                       1.525
# position_cost_long                                      68167.5
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                           1.525
# open_cost_long                                          68167.5
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                                1.523
# float_profit_long                                         -89.4
# float_profit_short                                            0
# float_profit                                              -89.4
# position_profit_long                                      -89.4
# position_profit_short                                         0
# position_profit                                           -89.4
#
#                                                 stock_cn.160322  \
# code                                                     160322
# instrument_id                                            160322
# user_id                                                 myacc12
# portfolio_cookie                                      portfolio
# username                                              quantaxis
# position_id                71315565-4692-46df-8620-a0d3630d3008
# account_cookie                                          myacc12
# frozen                                                       {}
# name                                                       港股精选
# spms_id                                                    None
# oms_id                                                     None
# market_type                                            stock_cn
# exchange_id                                                 sse
# moneypreset                                              100000
# moneypresetLeft                                          100000
# lastupdatetime
# volume_long_today                                             0
# volume_long_his                                            2800
# volume_long                                                2800
# volume_long_yd                                                0
# volume_short_yd                                               0
# volume_short_today                                            0
# volume_short_his                                              0
# volume_short                                                  0
# pos_long_his                                               2800
# pos_long_today                                                0
# pos_short_his                                                 0
# pos_short_today                                               0
# volume_long_frozen_today                                      0
# volume_long_frozen_his                                        0
# volume_long_frozen                                            0
# volume_short_frozen_today                                     0
# volume_short_frozen_his                                       0
# volume_short_frozen                                           0
# margin_long                                                   0
# margin_short                                                  0
# margin                                                        0
# position_price_long                                       1.796
# position_cost_long                                       5028.8
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                           1.796
# open_cost_long                                           5028.8
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                                1.714
# float_profit_long                                        -229.6
# float_profit_short                                            0
# float_profit                                             -229.6
# position_profit_long                                     -229.6
# position_profit_short                                         0
# position_profit                                          -229.6
#
#                                                 stock_cn.160631  ...  \
# code                                                     160631  ...
# instrument_id                                            160631  ...
# user_id                                                 myacc12  ...
# portfolio_cookie                                      portfolio  ...
# username                                              quantaxis  ...
# position_id                3b7c743d-5b69-4f96-8e7c-557b21056bba  ...
# account_cookie                                          myacc12  ...
# frozen                                                       {}  ...
# name                                                       银行指基  ...
# spms_id                                                    None  ...
# oms_id                                                     None  ...
# market_type                                            stock_cn  ...
# exchange_id                                                 sse  ...
# moneypreset                                              100000  ...
# moneypresetLeft                                          100000  ...
# lastupdatetime                                                   ...
# volume_long_today                                             0  ...
# volume_long_his                                            2447  ...
# volume_long                                                2447  ...
# volume_long_yd                                                0  ...
# volume_short_yd                                               0  ...
# volume_short_today                                            0  ...
# volume_short_his                                              0  ...
# volume_short                                                  0  ...
# pos_long_his                                               2447  ...
# pos_long_today                                                0  ...
# pos_short_his                                                 0  ...
# pos_short_today                                               0  ...
# volume_long_frozen_today                                      0  ...
# volume_long_frozen_his                                        0  ...
# volume_long_frozen                                            0  ...
# volume_short_frozen_today                                     0  ...
# volume_short_frozen_his                                       0  ...
# volume_short_frozen                                           0  ...
# margin_long                                                   0  ...
# margin_short                                                  0  ...
# margin                                                        0  ...
# position_price_long                                           1  ...
# position_cost_long                                         2447  ...
# position_price_short                                          0  ...
# position_cost_short                                           0  ...
# open_price_long                                               1  ...
# open_cost_long                                             2447  ...
# open_price_short                                              0  ...
# open_cost_short                                               0  ...
# trades                                                       []  ...
# orders                                                       {}  ...
# last_price                                                1.046  ...
# float_profit_long                                       112.562  ...
# float_profit_short                                            0  ...
# float_profit                                            112.562  ...
# position_profit_long                                    112.562  ...
# position_profit_short                                         0  ...
# position_profit                                         112.562  ...
#
#                                                 stock_cn.510900  \
# code                                                     510900
# instrument_id                                            510900
# user_id                                                 myacc12
# portfolio_cookie                                      portfolio
# username                                              quantaxis
# position_id                66b14f94-f679-432a-b107-022273270430
# account_cookie                                          myacc12
# frozen                                                       {}
# name                                                      H股ETF
# spms_id                                                    None
# oms_id                                                     None
# market_type                                            stock_cn
# exchange_id                                                 sse
# moneypreset                                              100000
# moneypresetLeft                                          100000
# lastupdatetime
# volume_long_today                                             0
# volume_long_his                                           14800
# volume_long                                               14800
# volume_long_yd                                                0
# volume_short_yd                                               0
# volume_short_today                                            0
# volume_short_his                                              0
# volume_short                                                  0
# pos_long_his                                              14800
# pos_long_today                                                0
# pos_short_his                                                 0
# pos_short_today                                               0
# volume_long_frozen_today                                      0
# volume_long_frozen_his                                        0
# volume_long_frozen                                            0
# volume_short_frozen_today                                     0
# volume_short_frozen_his                                       0
# volume_short_frozen                                           0
# margin_long                                                   0
# margin_short                                                  0
# margin                                                        0
# position_price_long                                       1.192
# position_cost_long                                      17641.6
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                           1.192
# open_cost_long                                          17641.6
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                                1.173
# float_profit_long                                        -281.2
# float_profit_short                                            0
# float_profit                                             -281.2
# position_profit_long                                     -281.2
# position_profit_short                                         0
# position_profit                                          -281.2
#
#                                                 stock_cn.512800  \
# code                                                     512800
# instrument_id                                            512800
# user_id                                                 myacc12
# portfolio_cookie                                      portfolio
# username                                              quantaxis
# position_id                4c9f7c53-0775-4866-b63f-a19e1a537e31
# account_cookie                                          myacc12
# frozen                                                       {}
# name                                                      银行ETF
# spms_id                                                    None
# oms_id                                                     None
# market_type                                            stock_cn
# exchange_id                                                 sse
# moneypreset                                              100000
# moneypresetLeft                                          100000
# lastupdatetime
# volume_long_today                                             0
# volume_long_his                                           30000
# volume_long                                               30000
# volume_long_yd                                                0
# volume_short_yd                                               0
# volume_short_today                                            0
# volume_short_his                                              0
# volume_short                                                  0
# pos_long_his                                              30000
# pos_long_today                                                0
# pos_short_his                                                 0
# pos_short_today                                               0
# volume_long_frozen_today                                      0
# volume_long_frozen_his                                        0
# volume_long_frozen                                            0
# volume_short_frozen_today                                     0
# volume_short_frozen_his                                       0
# volume_short_frozen                                           0
# margin_long                                                   0
# margin_short                                                  0
# margin                                                        0
# position_price_long                                      1.0995
# position_cost_long                                        32985
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                          1.0995
# open_cost_long                                            32985
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                                1.247
# float_profit_long                                          4425
# float_profit_short                                            0
# float_profit                                               4425
# position_profit_long                                       4425
# position_profit_short                                         0
# position_profit                                            4425
#
#                                                 stock_cn.600036  \
# code                                                     600036
# instrument_id                                            600036
# user_id                                                 myacc12
# portfolio_cookie                                      portfolio
# username                                              quantaxis
# position_id                2e938f06-b3d2-4c07-951c-f90b157cafab
# account_cookie                                          myacc12
# frozen                                                       {}
# name                                                       招商银行
# spms_id                                                    None
# oms_id                                                     None
# market_type                                            stock_cn
# exchange_id                                                 sse
# moneypreset                                              100000
# moneypresetLeft                                          100000
# lastupdatetime
# volume_long_today                                             0
# volume_long_his                                            3300
# volume_long                                                3300
# volume_long_yd                                                0
# volume_short_yd                                               0
# volume_short_today                                            0
# volume_short_his                                              0
# volume_short                                                  0
# pos_long_his                                               3300
# pos_long_today                                                0
# pos_short_his                                                 0
# pos_short_today                                               0
# volume_long_frozen_today                                      0
# volume_long_frozen_his                                        0
# volume_long_frozen                                            0
# volume_short_frozen_today                                     0
# volume_short_frozen_his                                       0
# volume_short_frozen                                           0
# margin_long                                                   0
# margin_short                                                  0
# margin                                                        0
# position_price_long                                     40.7353
# position_cost_long                                       134427
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                         40.7353
# open_cost_long                                           134427
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                                 56.4
# float_profit_long                                       51693.4
# float_profit_short                                            0
# float_profit                                            51693.4
# ...
# margin_short                                                  0
# margin                                                        0
# position_price_long                                     14.6738
# position_cost_long                                       472495
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                         14.6738
# open_cost_long                                           472495
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                                20.72
# float_profit_long                                        194689
# float_profit_short                                            0
# float_profit                                             194689
# position_profit_long                                     194689
# position_profit_short                                         0
# position_profit                                          194689
#
#                                                 stock_cn.601225  \
# code                                                     601225
# instrument_id                                            601225
# user_id                                                 myacc12
# portfolio_cookie                                      portfolio
# username                                              quantaxis
# position_id                b1edb1f4-1380-4c3d-8bd8-704d0eddf62c
# account_cookie                                          myacc12
# frozen                                                       {}
# name                                                       陕西煤业
# spms_id                                                    None
# oms_id                                                     None
# market_type                                            stock_cn
# exchange_id                                                 sse
# moneypreset                                              100000
# moneypresetLeft                                          100000
# lastupdatetime
# volume_long_today                                             0
# volume_long_his                                           15500
# volume_long                                               15500
# volume_long_yd                                                0
# volume_short_yd                                               0
# volume_short_today                                            0
# volume_short_his                                              0
# volume_short                                                  0
# pos_long_his                                              15500
# pos_long_today                                                0
# pos_short_his                                                 0
# pos_short_today                                               0
# volume_long_frozen_today                                      0
# volume_long_frozen_his                                        0
# volume_long_frozen                                            0
# volume_short_frozen_today                                     0
# volume_short_frozen_his                                       0
# volume_short_frozen                                           0
# margin_long                                                   0
# margin_short                                                  0
# margin                                                        0
# position_price_long                                       8.877
# position_cost_long                                       137593
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                           8.877
# open_cost_long                                           137593
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                                12.51
# float_profit_long                                       56311.5
# float_profit_short                                            0
# float_profit                                            56311.5
# position_profit_long                                    56311.5
# position_profit_short                                         0
# position_profit                                         56311.5
#
#                                                 stock_cn.601318  \
# code                                                     601318
# instrument_id                                            601318
# user_id                                                 myacc12
# portfolio_cookie                                      portfolio
# username                                              quantaxis
# position_id                c33946ae-51ce-472b-bb8e-fc21a0b07a98
# account_cookie                                          myacc12
# frozen                                                       {}
# name                                                       中国平安
# spms_id                                                    None
# oms_id                                                     None
# market_type                                            stock_cn
# exchange_id                                                 sse
# moneypreset                                              100000
# moneypresetLeft                                          100000
# lastupdatetime
# volume_long_today                                             0
# volume_long_his                                             900
# volume_long                                                 900
# volume_long_yd                                                0
# volume_short_yd                                               0
# volume_short_today                                            0
# volume_short_his                                              0
# volume_short                                                  0
# pos_long_his                                                900
# pos_long_today                                                0
# pos_short_his                                                 0
# pos_short_today                                               0
# volume_long_frozen_today                                      0
# volume_long_frozen_his                                        0
# volume_long_frozen                                            0
# volume_short_frozen_today                                     0
# volume_short_frozen_his                                       0
# volume_short_frozen                                           0
# margin_long                                                   0
# margin_short                                                  0
# margin                                                        0
# position_price_long                                      65.111
# position_cost_long                                      58599.9
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                          65.111
# open_cost_long                                          58599.9
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                                66.68
# float_profit_long                                        1412.1
# float_profit_short                                            0
# float_profit                                             1412.1
# position_profit_long                                     1412.1
# position_profit_short                                         0
# position_profit                                          1412.1
#
#                                                 stock_cn.601668  \
# code                                                     601668
# instrument_id                                            601668
# user_id                                                 myacc12
# portfolio_cookie                                      portfolio
# username                                              quantaxis
# position_id                8da5044d-5f3d-4dd3-83b9-783bc8f7556c
# account_cookie                                          myacc12
# frozen                                                       {}
# name                                                       中国建筑
# spms_id                                                    None
# oms_id                                                     None
# market_type                                            stock_cn
# exchange_id                                                 sse
# moneypreset                                              100000
# moneypresetLeft                                          100000
# lastupdatetime
# volume_long_today                                             0
# volume_long_his                                            2000
# volume_long                                                2000
# volume_long_yd                                                0
# volume_short_yd                                               0
# volume_short_today                                            0
# volume_short_his                                              0
# volume_short                                                  0
# pos_long_his                                               2000
# pos_long_today                                                0
# pos_short_his                                                 0
# pos_short_today                                               0
# volume_long_frozen_today                                      0
# volume_long_frozen_his                                        0
# volume_long_frozen                                            0
# volume_short_frozen_today                                     0
# volume_short_frozen_his                                       0
# volume_short_frozen                                           0
# margin_long                                                   0
# margin_short                                                  0
# margin                                                        0
# position_price_long                                       4.908
# position_cost_long                                         9816
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                           4.908
# open_cost_long                                             9816
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                                 4.92
# float_profit_long                                            24
# float_profit_short                                            0
# float_profit                                                 24
# position_profit_long                                         24
# position_profit_short                                         0
# position_profit                                              24
#
#                                                 stock_cn.601939
# code                                                     601939
# instrument_id                                            601939
# user_id                                                 myacc12
# portfolio_cookie                                      portfolio
# username                                              quantaxis
# position_id                1a6d073b-109f-4038-b6dd-72d33fb4ceff
# account_cookie                                          myacc12
# frozen                                                       {}
# name                                                       建设银行
# spms_id                                                    None
# oms_id                                                     None
# market_type                                            stock_cn
# exchange_id                                                 sse
# moneypreset                                              100000
# moneypresetLeft                                          100000
# lastupdatetime
# volume_long_today                                             0
# volume_long_his                                            3600
# volume_long                                                3600
# volume_long_yd                                                0
# volume_short_yd                                               0
# volume_short_today                                            0
# volume_short_his                                              0
# volume_short                                                  0
# pos_long_his                                               3600
# pos_long_today                                                0
# pos_short_his                                                 0
# pos_short_today                                               0
# volume_long_frozen_today                                      0
# volume_long_frozen_his                                        0
# volume_long_frozen                                            0
# volume_short_frozen_today                                     0
# volume_short_frozen_his                                       0
# volume_short_frozen                                           0
# margin_long                                                   0
# margin_short                                                  0
# margin                                                        0
# position_price_long                                        6.81
# position_cost_long                                        24516
# position_price_short                                          0
# position_cost_short                                           0
# open_price_long                                            6.81
# open_cost_long                                            24516
# open_price_short                                              0
# open_cost_short                                               0
# trades                                                       []
# orders                                                       {}
# last_price                                                 6.74
# float_profit_long                                          -252
# float_profit_short                                            0
# float_profit                                               -252
# position_profit_long                                       -252
# position_profit_short                                         0
# position_profit                                            -252
#
# [54 rows x 27 columns]

# %%
df.groupby('code').agg({'pos_num':'sum','cost':'mean','name':'first','currency':'first'}).reset_index().apply(lambda x:add_position(x),axis=1)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# dtype: object

# %%
my.balance
# Out:
# 1000000.0

# %%
def get_pos(stock):
    return QA_Position(
        code=stock['code'],
        account_cookie='myacc5',
        market_type=qa.MARKET_TYPE.STOCK_CN,
        exchange_id=qa.EXCHANGE_ID.SZSE if stock['code'][0] in (0,3) else qa.EXCHANGE_ID.SSE,
        volume_long_his=stock['pos'],
        volume_long_today=0,
        open_price_long=stock['price'],
        name=stock['name']
    )

# %%
for pos in cn_stock.apply(lambda x:get_pos(x),axis=1):
    my.add_position(pos)
